# %% [markdown]
# # GPU-Based Satellite Orbit Feasibility Simulator
#
# This notebook runs the CUDA simulator, generates CSV outputs, and creates the final visualization.
#
# Required project files in the same folder:
# - `satellite_sim.cu`
# - `visualize.py`
# - `Makefile`

# %%
# !nvidia-smi

# %%
# !apt-get update -qq
# !apt-get install -y -qq build-essential make
# !pip install -q pandas matplotlib numpy

# %%
# !make clean
# !make compile
# !./satellite_sim

# %%
# !python visualize.py

# %% [markdown]
# ## Generated Files
#
# After a successful run, these files should be created:
# - `orbit_results.csv`
# - `timing.csv`
# - `trajectory_samples.csv`
# - `orbit_visualization.png`

# %%
from IPython.display import Image, display
import os

if os.path.exists('orbit_visualization.png'):
    display(Image('orbit_visualization.png'))
else:
    print('orbit_visualization.png not found. Run the simulator and visualizer first.')
